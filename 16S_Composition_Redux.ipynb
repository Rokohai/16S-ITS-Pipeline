# %% [markdown]
# <a href="https://colab.research.google.com/github/Rokohai/16S-ITS-Pipeline/blob/main/16S_Composition_Redux.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/gregcaporaso/fq-manifestor.git

import os as os
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
# !bash miniconda.sh -b -p $HOME/miniconda
# !$HOME/miniconda/bin/conda init bash
conda_bin_path = os.path.expanduser('~/miniconda/bin')
os.environ['PATH'] = f"{conda_bin_path}:{os.environ['PATH']}"
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# !conda env create \
  --name qiime2-amplicon-2024.10 \
  --file https://raw.githubusercontent.com/qiime2/distributions/refs/heads/dev/2024.10/amplicon/released/qiime2-amplicon-ubuntu-latest-conda.yml
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# !cp -r /content/drive/MyDrive/Kombucha_Data_Analysis /content
# !cp -r /content/drive/MyDrive/Greengenes2_2024.09_from_515F806R_region_of_sequences.qza /content

# %%
# %cd /content/Kombucha_Data_Analysis/Stir16SUnzipped
# !git clone https://github.com/gregcaporaso/fq-manifestor.git
# %cd fq-manifestor

# !python fq-manifestor /content/Kombucha_Data_Analysis/Stir16SUnzipped fastq_manifest16S.tsv
# !cat fastq_manifest16S.tsv
# Out:
# /content/Kombucha_Data_Analysis/Stir16SUnzipped
# Cloning into 'fq-manifestor'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (20/20), done.
# Receiving objects: 100% (32/32), 10.13 KiB | 10.13 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# remote: Total 32 (delta 14), reused 28 (delta 11), pack-reused 0 (from 0)
# /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor
# Searching directory: /content/Kombucha_Data_Analysis/Stir16SUnzipped
# Found 72 fastq files.
# To import, try running:
# qiime tools import --type 'SampleData[PairedEndSequencesWithQuality]' --input-path /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv --output-path demux.qza --input-format PairedEndFastqManifestPhred33V2
# sample-id	forward-absolute-filepath	reverse-absolute-filepath
# ...

# %%
# !conda env update \
--name qiime2-amplicon-2024.10 \
--file https://raw.githubusercontent.com/caporaso-lab/q2-boots/refs/heads/main/environment-files/q2-boots-qiime2-amplicon-2024.10.yml
# !conda env update \
--name q2-kmerizer \
--file https://raw.githubusercontent.com/bokulich-lab/q2-kmerizer/refs/heads/main/environment-files/q2-kmerizer-qiime2-amplicon-2024.10.yml
# !conda env update \
--name q2-boots \
--file https://raw.githubusercontent.com/caporaso-lab/q2-boots/refs/heads/main/environment-files/q2-boots-qiime2-amplicon-2024.10.yml
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - https://packages.qiime2.org/qiime2/2024.10/amplicon/released
#  - conda-forge
#  - bioconda
#  - defaults
# Platform: linux-64
# done
# done
#
# ...
#
# done
# done
# done
# - Ran pip subprocess with arguments:
# ['/root/miniconda/envs/qiime2-amplicon-2024.10/bin/python', '-m', 'pip', 'install', '-U', '-r', '/tmp/condaenv.qwdl_nrv.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# ...
#      \ 2.8 MB 35.1 MB/s 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for q2-boots: filename=q2_boots-2024.10b0-py3-none-any.whl size=13955 sha256=4ef18c92d51cbb90efc4727cd1a6129a95820427de6339b08b35d559814f38aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m1e2why2/wheels/8a/79/da/832772ccafa2d0d9699d9d41272a6d458196cb102b4c7601e4
# Successfully built q2-boots
# ...
#
# done
# #
# # To activate this environment, use
# #
# ...

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime tools import \
  --type 'SampleData[PairedEndSequencesWithQuality]' \
  --input-path /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --input-format PairedEndFastqManifestPhred33V2 \
  --output-path /content/demux16S.qza
# Out:
# QIIME is caching your current deployment for improved performance. This may take a few moments and should only happen once per deployment.
# QIIME 2 environment activated
# Imported /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv as PairedEndFastqManifestPhred33V2 to /content/demux16S.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime demux summarize \
  --i-data /content/demux16S.qza \
  --o-visualization /content/demux16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/demux16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime dada2 denoise-paired \
  --i-demultiplexed-seqs /content/demux16S.qza \
  --p-trim-left-f 0 \
  --p-trunc-len-f 250 \
  --p-trim-left-r 0 \
  --p-trunc-len-r 250 \
  --o-representative-sequences /content/asv-seqs16S.qza \
  --o-table /content/asv-table16S.qza \
  --o-denoising-stats /content/stats16S.qza \
  --p-n-threads 8 \
  --verbose
# Out:
# QIIME 2 environment activated
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada.R --input_directory /tmp/tmpgqnaqhtm/forward --input_directory_reverse /tmp/tmpgqnaqhtm/reverse --output_path /tmp/tmpgqnaqhtm/output.tsv.biom --output_track /tmp/tmpgqnaqhtm/track.tsv --filtered_directory /tmp/tmpgqnaqhtm/filt_f --filtered_directory_reverse /tmp/tmpgqnaqhtm/filt_r --truncation_length 250 --truncation_length_reverse 250 --trim_left 0 --trim_left_reverse 0 --max_expected_errors 2.0 --max_expected_errors_reverse 2.0 --truncation_quality_score 2 --min_overlap 12 --pooling_method independent --chimera_method consensus --min_parental_fold 1.0 --allow_one_off False --num_threads 8 --learn_min_reads 1000000
#
# R version 4.3.3 (2024-02-29)
# Loading required package: Rcpp
# ...

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table summarize-plus \
  --i-table /content/asv-table16S.qza \
  --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --o-summary /content/asv-table16S.qzv \
  --o-sample-frequencies /content/sample-frequencies16S.qza \
  --o-feature-frequencies /content/asv-frequencies16S.qza
# Out:
# QIIME 2 environment activated
# Saved ImmutableMetadata to: /content/asv-frequencies16S.qza
# Saved ImmutableMetadata to: /content/sample-frequencies16S.qza
# Saved Visualization to: /content/asv-table16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime metadata tabulate \
  --m-input-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv /content/stats16S.qza \
  --o-visualization /content/sample-metadata-w-dada2-stats16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/sample-metadata-w-dada2-stats16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table tabulate-seqs \
  --i-data /content/asv-seqs16S.qza \
  --m-metadata-file /content/asv-frequencies16S.qza \
  --o-visualization /content/asv-seqs16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/asv-seqs16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table filter-features \
  --i-table /content/asv-table16S.qza \
  --p-min-samples 1 \
  --o-filtered-table /content/asv-table-ms1-16S.qza
# Out:
# QIIME 2 environment activated
# Saved FeatureTable[Frequency] to: /content/asv-table-ms1-16S.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime metadata tabulate \
  --m-input-file /content/stats16S.qza \
  --o-visualization /content/stats16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/stats16S.qzv

# %%
############# For this one make sure you look at asv-table-ms1.qzv file to see sampling depth
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table summarize \
  --i-table /content/asv-table-ms1-16S.qza \
  --m-sample-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --o-visualization /content/asv-table-ms1-16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/asv-table-ms1-16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table filter-seqs \
  --i-data /content/asv-seqs16S.qza \
  --i-table /content/asv-table-ms1-16S.qza \
  --o-filtered-data /content/asv-seqs-ms1-16S.qza
# Out:
# QIIME 2 environment activated
# Saved FeatureData[Sequence] to: /content/asv-seqs-ms1-16S.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table summarize-plus \
  --i-table /content/asv-table-ms1-16S.qza \
  --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --o-summary /content/asv-table-ms1-16S.qzv \
  --o-sample-frequencies /content/sample-frequencies-ms1-16S.qza \
  --o-feature-frequencies /content/asv-frequencies-ms1-16S.qza
# Out:
# QIIME 2 environment activated
# Saved ImmutableMetadata to: /content/asv-frequencies-ms1-16S.qza
# Saved ImmutableMetadata to: /content/sample-frequencies-ms1-16S.qza
# Saved Visualization to: /content/asv-table-ms1-16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-classifier classify-sklearn \
  --i-classifier /content/Greengenes2_2024.09_from_515F806R_region_of_sequences.qza \
  --i-reads /content/asv-seqs-ms1-16S.qza \
  --o-classification /content/taxonomy16S.qza
# Out:
# QIIME 2 environment activated
# Saved FeatureData[Taxonomy] to: /content/taxonomy16S.qza

# %%
##########
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table tabulate-seqs \
  --i-data /content/asv-seqs-ms1-16S.qza \
  --i-taxonomy /content/taxonomy16S.qza \
  --m-metadata-file /content/asv-frequencies-ms1-16S.qza \
  --o-visualization /content/asv-seqs-ms1-16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/asv-seqs-ms1-16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table tabulate-seqs \
  --i-data /content/asv-seqs-ms1-16S.qza \
  --i-taxonomy /content/taxonomy16S.qza \
  --m-metadata-file /content/asv-frequencies-ms1-16S.qza \
  --o-visualization /content/asv-seqs-ms1-16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/asv-seqs-ms1-16S.qzv

# %%
#Check depth beforehand
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime diversity alpha-rarefaction \
  --i-table /content/asv-table-ms1-16S.qza \
  --p-max-depth 28486 \
  --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --o-visualization /content/alpha-rarefaction16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/alpha-rarefaction16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime taxa barplot \
  --i-table /content/asv-table-ms1-16S.qza \
  --i-taxonomy /content/taxonomy16S.qza \
  --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --o-visualization /content/taxa-bar-plots16S.qzv
# Out:
# QIIME 2 environment activated
# Saved Visualization to: /content/taxa-bar-plots16S.qzv

# %%
# --o-scatter-plot /content/scatter_plot_core_metricsPCOA_16S.qzv wouldn't work
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && conda activate q2-boots && echo "QIIME 2 environment activated" && qiime boots core-metrics \
  --i-table /content/asv-table-ms1-16S.qza \
  --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --p-sampling-depth 28486 \
  --p-n 10 \
  --p-no-replacement \
  --p-alpha-average-method median \
  --p-beta-average-method medoid \
  --output-dir /content/boots-core-metrics \
  --o-resampled-tables /content/boots-core-metrics/resampled_tables16S.qza \
  --o-alpha-diversities /content/boots-core-metrics/alpha_diversities16S.qza \
  --o-distance-matrices /content/boots-core-metrics/distance_matrices16S.qza \
  --o-pcoas /content/boots-core-metrics/pcoas16S.qza \
  --o-emperor-plots /content/boots-core-metrics/emperor_plots16S.qza \
  --o-scatter-plot /content/scatter_plot_core_metricsPCOA_16S.qzv
# Out:
# QIIME 2 environment activated
# Usage: qiime boots core-metrics
#            [OPTIONS]
#
#   Given a single feature table as input, this
#   action resamples the feature table `n` times to
#   a total frequency of `sampling depth` per
#   sample, and then computes common alpha and beta
#   diversity on each resulting `table`. The
#   resulting artifacts are then averaged using the
#   method specified by `alpha_average_method` and
#   `beta_average_method` parameters. The resulting
#   average alpha and beta diversity artifacts are
#   returned, along with PCoA matrices and Emperor
#   plots.
#
# Inputs:
#   --i-table ARTIFACT FeatureTable[Frequency |
#     RelativeFrequency | PresenceAbsence]
#                           The input feature
#                           table.        [required]
#   --i-phylogeny ARTIFACT  The phylogenetic tree
#     Phylogeny[Rooted]     to use in phylogenetic
#                           diversity calculations.
# ...

# %%
####
# https://library.qiime2.org/plugins/caporaso-lab/q2-boots/overview#q2-action-boots-kmer-diversity
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && conda activate q2-boots && echo "QIIME 2 environment activated" && qiime boots kmer-diversity \
  --i-table /content/asv-table-ms216S.qza \
  --i-sequences /content/asv-seqs-ms216S.qza \
  --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --p-sampling-depth 28486 \
  --p-n 10 \
  --p-replacement \
  --p-alpha-average-method median \
  --p-beta-average-method medoid \
  --output-dir /content/kmer_diversity_output \
  --o-resampled-tables /content/kmer_diversity_output/resampled_tables16S.qza \
  --o-kmer-tables /content/kmer_diversity_output/kmer_tables16S.qza \
  --o-alpha-diversities /content/kmer_diversity_output/alpha_diversities16S.qza \
  --o-distance-matrices /content/kmer_diversity_output/distance_matrices16S.qza \
  --o-pcoas /content/kmer_diversity_output/pcoas16S.qza \
  --o-scatter-plot /content/scatter_plot_kmer_diversityPCOA_16S.qzv
# Out:
# QIIME 2 environment activated
# Error: QIIME 2 plugin 'boots' has no action 'kmer-diversity'.

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime phylogeny align-to-tree-mafft-fasttree \
  --i-sequences rep-seqs.qza \
  --o-alignment aligned-rep-seqs.qza \
  --o-masked-alignment masked-aligned-rep-seqs.qza \
  --o-tree unrooted-tree.qza \
  --o-rooted-tree rooted-tree.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime diversity beta-phylogenetic \
  --i-table table-rarefied.qza \
  --i-phylogeny rooted-tree.qza \
  --p-metric weighted_unifrac \
  --o-distance-matrix weighted-unifrac-distance.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime diversity beta-group-significance \
 --i-distance-matrix weighted-unifrac-distance16S.qza \
 --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
 --m-metadata-column \
 --p-method 'permanova' \
 --p-pairwise True \
 --o-visualization permanova16S.qzv \
 --verbose

# %%
###################################
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table summarize-plus \
  --i-table /content/asv-table16S.qza \
  --m-metadata-file /content/Kombucha_Data_Analysis/Stir16SUnzipped/fq-manifestor/fastq_manifest16S.tsv \
  --o-summary /content/asv-tableITSAutoclaved_Sweet_Tea.qzv \
  --o-sample-frequencies /content/sample-frequencies16S.qza \
  --o-feature-frequencies /content/asv-frequencies16S.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table tabulate-seqs \
  --i-data /content/asv-seqs16S.qza \
  --m-metadata-file /content/asv-frequencies16S.qza \
  --o-visualization /content/asv-seq16S.qzv

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table filter-features \
  --i-table /content/asv-table16S.qza \
  --p-min-samples 1 \
  --o-filtered-table /content/asv-table-ms1ITSAutoclaved_Sweet_Tea.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table filter-seqs \
  --i-data /content/asv-seqsITSAutoclaved_Sweet_Tea.qza \
  --i-table /content/asv-table-ms1ITSAutoclaved_Sweet_Tea.qza \
  --o-filtered-data /content/asv-seqs-ms1ITSAutoclaved_Sweet_Tea.qza

# %%
# !source $HOME/miniconda/etc/profile.d/conda.sh && conda activate qiime2-amplicon-2024.10 && echo "QIIME 2 environment activated" && qiime feature-table summarize-plus \
  --i-table /content/asv-table-ms1ITSAutoclaved_Sweet_Tea.qza \
  --m-metadata-file /content/Autoclaved_Sweet_Tea/fq-manifestor/fastq_manifestITSAutoclaved_Sweet_Tea.tsv \
  --o-summary /content/asv-table-ms1ITSAutoclaved_Sweet_Tea.qzv \
  --o-sample-frequencies /content/sample-frequencies-ms1ITSAutoclaved_Sweet_Tea.qza \
  --o-feature-frequencies /content/asv-frequencies-ms1ITSAutoclaved_Sweet_Tea.qza

# %%
## PERMANOVA in QIIME2
Usage: qiime diversity beta-group-significance [OPTIONS]

  Determine whether groups of samples are significantly different from one
  another using a permutation-based statistical test.

Inputs:
  --i-distance-matrix ARTIFACT
    DistanceMatrix       Matrix of distances between pairs of samples.
                                                                    [required]
Parameters:
  --m-metadata-file METADATA
  --m-metadata-column COLUMN  MetadataColumn[Categorical]
                         Categorical sample metadata column.        [required]
  --p-method TEXT Choices('permanova', 'anosim', 'permdisp')
                         The group significance test to be applied.
                                                        [default: 'permanova']
  --p-pairwise / --p-no-pairwise
                         Perform pairwise tests between all pairs of groups
                         in addition to the test across all groups. This can
                         be very slow if there are a lot of groups in the
                         metadata column.                     [default: False]
  --p-permutations INTEGER
                         The number of permutations to be run when computing
                         p-values.                              [default: 999]
Outputs:
  --o-visualization VISUALIZATION
                                                                    [required]
Miscellaneous:
  --output-dir PATH      Output unspecified results to a directory
  --verbose / --quiet    Display verbose output to stdout and/or stderr
                         during execution of this action. Or silence output if
                         execution is successful (silence is golden).
  --example-data PATH    Write example data and exit.
  --citations            Show citations and exit.
  --use-cache DIRECTORY  Specify the cache to be used for the intermediate
                         work of this action. If not provided, the default
                         cache under $TMP/qiime2/ will be used.
                         IMPORTANT FOR HPC USERS: If you are on an HPC system
                         and are using parallel execution it is important to
                         set this to a location that is globally accessible to
                         all nodes in the cluster.
  --help                 Show this message and exit.
